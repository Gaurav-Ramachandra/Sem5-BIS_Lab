# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav-Ramachandra/Sem5-BIS_Lab/blob/main/Expt4%2014-11%3A%20Cuckoo_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math

def levy_flight(beta, size):
    """Generate steps for Levy flight."""
    sigma_u = (math.gamma(1 + beta) * np.sin(np.pi * beta / 2) /
               (math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
    u = np.random.normal(0, sigma_u, size)
    v = np.random.normal(0, 1, size)
    step = u / np.abs(v) ** (1 / beta)
    return step

def fitness_function(solution):
    """Define the objective function to optimize."""
    return np.sum(solution ** 2)  # Example: Sphere function

def generate_random_solution(lower_bound, upper_bound, dim):
    """Generate a random solution within bounds."""
    return lower_bound + (upper_bound - lower_bound) * np.random.rand(dim)

def cuckoo_search(nests, fitness, pa, alpha, beta, max_generations, lower_bound, upper_bound):
    """Cuckoo Search Algorithm."""
    n, dim = nests.shape
    best_solution = nests[np.argmin(fitness)]
    best_fitness = np.min(fitness)

    for generation in range(max_generations):
        # Generate a new solution via Levy flight
        new_nests = np.copy(nests)
        for i in range(n):
            step = alpha * levy_flight(beta, dim)
            new_solution = nests[i] + step
            new_solution = np.clip(new_solution, lower_bound, upper_bound)

            new_fitness = fitness_function(new_solution)
            if new_fitness < fitness[i]:
                new_nests[i] = new_solution
                fitness[i] = new_fitness

        # Discovery and randomization
        for i in range(n):
            if np.random.rand() < pa:
                new_nests[i] = generate_random_solution(lower_bound, upper_bound, dim)
                fitness[i] = fitness_function(new_nests[i])

        # Update the best solution
        current_best = np.argmin(fitness)
        if fitness[current_best] < best_fitness:
            best_solution = new_nests[current_best]
            best_fitness = fitness[current_best]

        nests = new_nests

        print(f"Generation {generation + 1}: Best fitness = {best_fitness}")

    return best_solution, best_fitness

# Parameters
n = 20  # Number of nests
pa = 0.25  # Discovery rate
alpha = 0.01  # Step size
beta = 1.5  # Levy flight parameter
max_generations = 100
lower_bound = -10  # Lower bound of the search space
upper_bound = 10  # Upper bound of the search space
dim = 5  # Dimensionality of the problem

# Initialize nests and fitness
nests = np.array([generate_random_solution(lower_bound, upper_bound, dim) for _ in range(n)])
fitness = np.array([fitness_function(nest) for nest in nests])

# Run the Cuckoo Search algorithm
best_solution, best_fitness = cuckoo_search(nests, fitness, pa, alpha, beta, max_generations, lower_bound, upper_bound)

print("Best solution:", best_solution)
print("Best fitness:", best_fitness)
# Out:
# Generation 1: Best fitness = 62.74271847250526
# Generation 2: Best fitness = 62.74271847250526
# Generation 3: Best fitness = 62.74271847250526
# Generation 4: Best fitness = 62.74271847250526
# Generation 5: Best fitness = 60.28437135096651
# Generation 6: Best fitness = 44.53861264070263
# Generation 7: Best fitness = 44.5310991354925
# Generation 8: Best fitness = 44.5310991354925
# Generation 9: Best fitness = 44.5310991354925
# Generation 10: Best fitness = 44.5310991354925
# Generation 11: Best fitness = 44.5310991354925
# Generation 12: Best fitness = 44.5310991354925
# Generation 13: Best fitness = 44.5310991354925
# Generation 14: Best fitness = 44.5310991354925
# Generation 15: Best fitness = 44.5310991354925
# Generation 16: Best fitness = 44.5310991354925
# Generation 17: Best fitness = 44.5310991354925
# Generation 18: Best fitness = 44.5310991354925
# Generation 19: Best fitness = 44.5310991354925
# Generation 20: Best fitness = 28.805397098236767
# Generation 21: Best fitness = 18.902080515936127
# Generation 22: Best fitness = 18.65527518428372
# Generation 23: Best fitness = 18.65527518428372
# Generation 24: Best fitness = 18.65527518428372
# Generation 25: Best fitness = 18.601002378139057
# Generation 26: Best fitness = 18.5453066745041
# Generation 27: Best fitness = 18.5453066745041
# Generation 28: Best fitness = 14.612121588494382
# Generation 29: Best fitness = 14.594900240292262
# Generation 30: Best fitness = 14.594900240292262
# Generation 31: Best fitness = 14.594900240292262
# Generation 32: Best fitness = 14.594900240292262
# Generation 33: Best fitness = 14.594900240292262
# Generation 34: Best fitness = 14.594900240292262
# Generation 35: Best fitness = 14.594900240292262
# Generation 36: Best fitness = 14.594900240292262
# Generation 37: Best fitness = 14.594900240292262
# Generation 38: Best fitness = 14.594900240292262
# Generation 39: Best fitness = 14.594900240292262
# Generation 40: Best fitness = 14.594900240292262
# Generation 41: Best fitness = 14.594900240292262
# Generation 42: Best fitness = 14.594900240292262
# Generation 43: Best fitness = 14.594900240292262
# Generation 44: Best fitness = 14.594900240292262
# Generation 45: Best fitness = 14.594900240292262
# Generation 46: Best fitness = 14.594900240292262
# Generation 47: Best fitness = 14.594900240292262
# Generation 48: Best fitness = 14.594900240292262
# Generation 49: Best fitness = 14.594900240292262
# Generation 50: Best fitness = 14.594900240292262
# Generation 51: Best fitness = 14.594900240292262
# Generation 52: Best fitness = 14.594900240292262
# Generation 53: Best fitness = 14.594900240292262
# Generation 54: Best fitness = 14.594900240292262
# Generation 55: Best fitness = 14.594900240292262
# Generation 56: Best fitness = 14.594900240292262
# Generation 57: Best fitness = 14.594900240292262
# Generation 58: Best fitness = 14.594900240292262
# Generation 59: Best fitness = 14.594900240292262
# Generation 60: Best fitness = 14.594900240292262
# Generation 61: Best fitness = 14.594900240292262
# Generation 62: Best fitness = 14.594900240292262
# Generation 63: Best fitness = 14.594900240292262
# Generation 64: Best fitness = 14.594900240292262
# Generation 65: Best fitness = 14.594900240292262
# Generation 66: Best fitness = 14.594900240292262
# Generation 67: Best fitness = 14.594900240292262
# Generation 68: Best fitness = 14.594900240292262
# Generation 69: Best fitness = 14.594900240292262
# Generation 70: Best fitness = 14.594900240292262
# Generation 71: Best fitness = 14.594900240292262
# Generation 72: Best fitness = 14.594900240292262
# Generation 73: Best fitness = 14.594900240292262
# Generation 74: Best fitness = 14.594900240292262
# Generation 75: Best fitness = 14.594900240292262
# Generation 76: Best fitness = 14.594900240292262
# Generation 77: Best fitness = 14.594900240292262
# Generation 78: Best fitness = 14.594900240292262
# Generation 79: Best fitness = 14.594900240292262
# Generation 80: Best fitness = 14.594900240292262
# Generation 81: Best fitness = 14.594900240292262
# Generation 82: Best fitness = 14.594900240292262
# Generation 83: Best fitness = 14.594900240292262
# Generation 84: Best fitness = 14.594900240292262
# Generation 85: Best fitness = 14.594900240292262
# Generation 86: Best fitness = 14.594900240292262
# Generation 87: Best fitness = 14.594900240292262
# Generation 88: Best fitness = 14.594900240292262
# Generation 89: Best fitness = 14.594900240292262
# Generation 90: Best fitness = 14.594900240292262
# Generation 91: Best fitness = 14.594900240292262
# Generation 92: Best fitness = 14.594900240292262
# Generation 93: Best fitness = 14.594900240292262
# Generation 94: Best fitness = 14.594900240292262
# Generation 95: Best fitness = 14.594900240292262
# Generation 96: Best fitness = 14.594900240292262
# Generation 97: Best fitness = 14.594900240292262
# Generation 98: Best fitness = 14.594900240292262
# Generation 99: Best fitness = 14.594900240292262
# Generation 100: Best fitness = 14.594900240292262
# Best solution: [ 0.81991488 -0.04755649  2.79399009 -0.37052093  2.44473145]
# Best fitness: 14.594900240292262
